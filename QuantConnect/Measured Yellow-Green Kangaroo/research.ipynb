# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# first we call quantbook

# %%
qb = QuantBook()

fb = qb.AddEquity('FB')
aapl = qb.AddEquity('AAPL')
goog = qb.AddEquity('GOOG')

# %%
bb_indicator = BollingerBands(30,2)
bb_data = qb.Indicator(bb_indicator,fb.Symbol,365,Resolution.Daily)

# %%
bb_data

# %%
bb_data.drop(["standarddeviation", "percentb", "bandwidth"],axis=1).plot()
